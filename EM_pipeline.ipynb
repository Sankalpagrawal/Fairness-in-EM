# %%
import sys
# sys.path.append('/Users/Sankalp Agrawalcdsas/Documents/Research/Python-Package/anhaid/py_entitymatching/')

import py_entitymatching as em
import pandas as pd
import os

# %%
# Display the versions
print('python version: ' + sys.version )
print('pandas version: ' + pd.__version__ )
print('magellan version: ' + em.__version__ )
# Out:
# python version: 3.6.12 |Anaconda, Inc.| (default, Sep  9 2020, 00:29:25) [MSC v.1916 64 bit (AMD64)]
# pandas version: 0.23.4
# magellan version: 0.3.1

# %%
# path_A = em.get_install_path() + os.sep + 'datasets' + os.sep + 'end-to-end' + os.sep + 'restaurants/fodors.csv'
# path_B = em.get_install_path() + os.sep + 'datasets' + os.sep + 'end-to-end' + os.sep + 'restaurants/zagats.csv'
path_A = 'movies1.csv'
path_B = 'movies2.csv'

# %%
# Load csv files as dataframes and set the key attribute in the dataframe
A = em.read_csv_metadata(path_A, key='Id')
B = em.read_csv_metadata(path_B, key='Id')
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
print('Number of tuples in A: ' + str(len(A)))
print('Number of tuples in B: ' + str(len(B)))
print('Number of tuples in A X B (i.e the cartesian product): ' + str(len(A)*len(B)))
# Out:
# Number of tuples in A: 7390
# Number of tuples in B: 6407
# Number of tuples in A X B (i.e the cartesian product): 47347730

# %%
# print(A.head(2))
# print(B.head(2))
# Display the keys of the input tables
print(em.get_key(A), em.get_key(B))
# If the tables are large we can downsample the tables like this
A1, B1 = em.down_sample(A, B, 200, 1, show_progress=False)
print(len(A1), len(B1))

# But for the purposes of this notebook, we will use the entire table A and B
# Out:
# Id Id
# 174 200

# %%
# Replacing NaN with ""
A = A.fillna("")
B = B.fillna("")

# %%
B
# Out:
#                                                 Id  \
# 0                            city_of_missing_girls
# 1                                     gay_divorcee
# 2                                         divorcee
# 3                   1009470-hells_angels_on_wheels
# 4                           the-miracle-woman-1932
# 5                                    trader_hornee
# 6                                    miracle_woman
# 7                    1006206-dr_jekyll_and_mr_hyde
# 8                    1006207-dr_jekyll_and_mr_hyde
# 9                                  animal_crackers
# 10                   1006208-dr_jekyll_and_mr_hyde
# 11                                     trader_horn
# 12                                big_mommas_house
# 13                               frankenstein_2015
# 14                            1007818-frankenstein
# 15                                       big_house
# 16                            tcm_presents_dracula
# 17                      1154157-big_mommas_house_2
# 18                         1038237-platinum_blonde
# 19                                 1006236-dracula
# 20                                    hells_angels
# 21                       our-daily-bread-city-girl
# 22                                 1006234-dracula
# 23          1000642-all_quiet_on_the_western_front
# 24                         1014137-monkey_business
# 25                                   little_caesar
# 26                               night-call-nurses
# 27                             1035050-night_nurse
# 28                        last_flight_of_noahs_ark
# 29                         1014138-monkey_business
# ...                                            ...
# 6377                                 hardcore_2005
# 6378                                     lila_says
# 6379                                  lila_and_eve
# 6380                              1009219-hardcore
# 6381                                    regression
# 6382                                 nocturna_2004
# 6383                                 nocturna_1979
# 6384                                parallels_2015
# 6385                                   nightlights
# 6386                                 49th_parallel
# 6387                                 sector_7_2011
# 6403  1 hr. 30 min.
# 6404  1 hr. 34 min.  4.8/10,4.6/10
# 6405  1 hr. 22 min.         7.1/10
# 6406                        6.2/10
#
#                                                                               ContentRating  \
# 0                                                                                   Unrated
# 1                                                                                   Unrated
# 2                                                                                   Unrated
# 3                                                                                         R
# 4                                                                                   Unrated
# 5                                                                                         R
# 6                                                                                   Unrated
# 7                                                                                   Unrated
# 8                                                                                   Unrated
# 9                                                                                         G
# 10                                                                                  Unrated
# 11                                                                                  Unrated
# 12    PG-13 (for crude humor including sexual innuendo, and for language and some violence)
# 13                       PG-13 (for macabre images, vioelnce and a sequence of destruction)
# 14                                                                                  Unrated
# 15                                                                                  Unrated
# 16                                                                                  Unrated
# 17                              PG-13 (for some sexual humor and a humorous drug reference)
# 18                                                                                  Unrated
# 19                                                                                        R
# 20                                                                                       PG
# 21                                                                                  Unrated
# 22                                                                                  Unrated
# 23                                                                                       PG
# 24                                                                                  Unrated
# 25                                                                                  Unrated
# 26                                               R (adult situations/language, nudity, sex)
# 27                                                                                  Unrated
# 28                                                                                        G
# 29                                                                                       PG
# ...                                                                                     ...
# 6377                                                                                Unrated
# 6378                                                                                      R
# 6379                                                          R (for violence and language)
# 6380                                                                                      R
# 6381                                                                                Unrated
# 6382                                                                                Unrated
# 6383                                                                                      R
# 6384                                                                                Unrated
# 6385                                                                                Unrated
# 6386                                                                                Unrated
# 6387                                                                                Unrated
# 6388                                                                                Unrated
# 6389             R (for language throughout including sexual references, and some violence)
# 6390                                                                                Unrated
# 6391                                                                                Unrated
# 6392                                                                                Unrated
# 6393                                                                                Unrated
# 6394                                                                                     PG
# 6395                                                                                      R
# 6396                                                                          PG (violence)
# 6397                                   R (for strong violence, language and some sexuality)
# 6398                                                                                Unrated
# 6399                           PG-13 (for violence, some action and brief strong language.)
# 6400                                                                                Unrated
# 6401                                                                                      R
# 6402                                                R (adult situations/language, violence)
# 6403                                              R (for bloody violence and some language)
# 6404                                              R (for language and some sexual material)
# 6405                                                                                Unrated
# 6406                                PG-13 (for thematic material and brief strong language)
#
#                                                                                                     Genre  \
# 0                                                                       Drama,Mystery & Suspense,Classics
# 1                                                 Drama,Romance,Musical & Performing Arts,Classics,Comedy
# 2                                                                                  Drama,Romance,Classics
# 3                                                                             Classics,Action & Adventure
# 4                                                                                                   Drama
# 5                                                                      Action & Adventure,Classics,Comedy
# 6                                                                                            Drama,Comedy
# 7                                                         Drama,Horror,Classics,Science Fiction & Fantasy
# 8                                                                                            Drama,Horror
# 9                                                                                         Classics,Comedy
# 10                                                        Drama,Horror,Classics,Science Fiction & Fantasy
# 11                                                                            Classics,Action & Adventure
# 12                                                                              Action & Adventure,Comedy
# 13                                                                                                  Drama
# 14                                             Horror,Classics,Science Fiction & Fantasy,Special Interest
# 15                                                                                         Drama,Classics
# 16                                                                                Horror,Special Interest
# 17                                                                                                 Comedy
# 18                                                                                Romance,Classics,Comedy
# 19                                                         Drama,Horror,Romance,Art House & International
# 20                                                                      Drama,Action & Adventure,Classics
# 21                                                                                 Drama,Romance,Classics
# 22                                                                                        Classics,Horror
# 23                                                                                         Drama,Classics
# 24                                                                                        Classics,Comedy
# 25                                                                                         Drama,Classics
# 26                                                  Action & Adventure,Horror,Classics,Comedy,Cult Movies
# 27                                                                                                  Drama
# 28                                                                       Action & Adventure,Kids & Family
# 29                                                        Drama,Classics,Science Fiction & Fantasy,Comedy
# ...                                                                                                   ...
# 6377                                                                      Art House & International,Drama
# 6378                                                                      Art House & International,Drama
# 6379                                                                                                Drama
# 6380                                                                                                Drama
# 6381                                                                             Mystery & Suspense,Drama
# 6382                                                    Animation,Kids & Family,Science Fiction & Fantasy
# 6383                                                                                        Horror,Comedy
# 6384                                                         Action & Adventure,Science Fiction & Fantasy
# 6385                                                                                        Drama,Romance
# 6386                                                 Drama,Action & Adventure,Mystery & Suspense,Classics
# 6387                                                  Action & Adventure,Horror,Art House & International
# 6388                                                                                     Special Interest
# 6389                                                                            Mystery & Suspense,Horror
# 6390                                                                                          Documentary
# 6391                                                                         Documentary,Special Interest
# 6392                                                                                          Documentary
# 6393                                                                      Art House & International,Drama
# 6394                                                                                     Western,Classics
# 6395                                                                             Mystery & Suspense,Drama
# 6396                                                         Action & Adventure,Mystery & Suspense,Comedy
# 6397                                                                                   Action & Adventure
# 6398                                                         Action & Adventure,Science Fiction & Fantasy
# 6399                                                                Mystery & Suspense,Action & Adventure
# 6400                                      Action & Adventure,Art House & International,Mystery & Suspense
# 6401                                                          Drama,Action & Adventure,Mystery & Suspense
# 6402                                                                                     Drama,Television
# 6403                                                                                   Action & Adventure
# 6404  Action & Adventure,Art House & International,Documentary,Drama,Science Fiction & Fantasy,Special...
# 6405                                                                               Documentary,Television
# 6406                                                                                                Drama
#
#                                                                                 Url  \
# 0                            http://www.rottentomatoes.com/m/city_of_missing_girls/
# 1                                     http://www.rottentomatoes.com/m/gay_divorcee/
# 2                                         http://www.rottentomatoes.com/m/divorcee/
# 3                   http://www.rottentomatoes.com/m/1009470-hells_angels_on_wheels/
# 4                           http://www.rottentomatoes.com/m/the-miracle-woman-1932/
# 5                                    http://www.rottentomatoes.com/m/trader_hornee/
# 6                                    http://www.rottentomatoes.com/m/miracle_woman/
# 7                    http://www.rottentomatoes.com/m/1006206-dr_jekyll_and_mr_hyde/
# 8                    http://www.rottentomatoes.com/m/1006207-dr_jekyll_and_mr_hyde/
# 9                                  http://www.rottentomatoes.com/m/animal_crackers/
# 10                   http://www.rottentomatoes.com/m/1006208-dr_jekyll_and_mr_hyde/
# 11                                     http://www.rottentomatoes.com/m/trader_horn/
# 12                                http://www.rottentomatoes.com/m/big_mommas_house/
# 13                               http://www.rottentomatoes.com/m/frankenstein_2015/
# 14                            http://www.rottentomatoes.com/m/1007818-frankenstein/
# 15                                       http://www.rottentomatoes.com/m/big_house/
# 16                            http://www.rottentomatoes.com/m/tcm_presents_dracula/
# 17                      http://www.rottentomatoes.com/m/1154157-big_mommas_house_2/
# 6386  49th Parallel is a British wartime entreaty for Empire solidarity, concentrating on rousing the ...
# 6387  A viral creature stalks an oil rig crew working off the southern tip of Korea's Jeju Island afte...
# 6388  Don't miss Olivier Award winner and Poirot star David Suchet as the formidable Lady Bracknell in...
# 6389  For years, the Covington forest has been shrouded in mystery, with a dark past as a final destin...
# 6390  When Calgarian Robert Cohen moved to L.A. to pursue his dreams of becoming a comedy writer, he q...
# 6391  Megan Mylan and Jon Shenk's award-winning documentary Lost Boys of Sudan examines what happens w...
# 6392  Being Evel tells not just the incredible story behind the myth of 1970s American daredevil icon ...
# 6393  While strutting through Downtown Seoul, Hang-gi, a local gangland pimp, spots young Sun-hwa, a p...
# 6394  In this comic western, Flagg is an aging marshal who is dismayed to find that his old enemy, McK...
# 6395  Daniel Millican's thriller A Promise Kept features Sean Patrick Flanery as police detective Ben ...
# 6396  When a couple of inept cops are kicked off the police force, they decide to attempt to make thei...
# 6397  THE GUNMAN, the new action thriller from Pierre Morel, the director of Taken, stars Sean Penn, J...
# 6398  An astronaut is on a routine mission in space when he sees the beginning and the end of WW III. ...
# 6399  After being mysteriously framed for a terrorist bombing, a Foreign Service Officer (Milla Jovovi...
# 6400  An ensemble-flavored police drama from South Korean director Kim Yu-jin, Wild Card follows a gro...
# 6401  Simon West directs this remake of the 1987 Burt Reynold action thriller in this Sierra/Affinity ...
# 6402  Based on a true story, Vendetta tells the shocking and tragic story of a group of Sicilian immig...
# 6403  Dean Cain and WWE Superstar The Big Show star in 'Vendetta,' an action-packed thriller about a d...
# 6404  In the aftermath of the BP oil spill, an idealistic but imperfect New Orleans politician finds h...
# 6405  Filmmaker and film activist Pip Chodorov offers this affectionate overview of some of the leadin...
# 6406  In 1961, social psychologist Stanley Milgram conducted the 'obedience experiments' at Yale Unive...
#
# [6407 rows x 13 columns]

# %% [markdown]
# Blocking

# %%
# Create attribute equivalence blocker
ab = em.AttrEquivalenceBlocker()

# Block using Director attribute
C1 = ab.block_tables(A, B, "Director","Director",
                    l_output_attrs=["Name", "ReleaseDate", "Director", "Creator", "Cast", "Language" ,"Country", "Genre"], 
                    r_output_attrs=["Name", "ReleaseDate", "Director", "Creator", "Cast", "ContentRating", "Genre"]
                    )


l_prev=["Name", "Release Date", "Director", "Creator", "Cast", "Language" ,"Country", "Genre"]
r_prev=["Name", "ReleaseDate", "Director", "Creator", "Cast", "ContentRating", "Genre"]

colA = ["Id","Name","Year","Release Date","Director","Creator","Actors","Cast","Language","Country","Duration","RatingValue","RatingCount","ReviewCount","Genre","Filming Locations","Description"]
colB = ["Id","Name","YearRange","ReleaseDate","Director","Creator","Cast","Duration","RatingValue","ContentRating","Genre","Url","Description"]
# Out:
# DataFrame information is not present in the catalog
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-345bbfdd2493> in <module>
#       5 C1 = ab.block_tables(A, B, "Director","Director",
#       6                     l_output_attrs=["Id","Name", "ReleaseDate", "Director", "Creator", "Cast", "Language" ,"Country", "Genre"],
# ----> 7                     r_output_attrs=["Id","Name", "ReleaseDate", "Director", "Creator", "Cast", "ContentRating", "Genre"]
#       8                     )
#       9
#
# ~\anaconda3\envs\em-env\lib\site-packages\py_entitymatching\blocker\attr_equiv_blocker.py in block_tables(self, ltable, rtable, l_block_attr, r_block_attr, l_output_attrs, r_output_attrs, l_output_prefix, r_output_prefix, allow_missing, verbose, n_jobs)
#     151         # # get metadata
#     152         l_key, r_key = cm.get_keys_for_ltable_rtable(ltable, rtable, logger,
# --> 153                                                      verbose)
#     154
#     155         # # validate metadata
#
# ~\anaconda3\envs\em-env\lib\site-packages\py_entitymatching\catalog\catalog_manager.py in get_keys_for_ltable_rtable(ltable, rtable, lgr, verbose)
#    1272     ch.log_info(lgr, 'Getting metadata from the catalog', verbose)
#    1273     # Get the ltable key and rtable key from the catalog
# -> 1274     ltable_key = get_key(ltable)
#    1275     rtable_key = get_key(rtable)
#    1276     ch.log_info(lgr, '..... Done', verbose)
#
# ~\anaconda3\envs\em-env\lib\site-packages\py_entitymatching\catalog\catalog_manager.py in get_key(data_frame)
#     659     """
#     660     # This function is just a sugar to get the 'key' property for a DataFrame
# --> 661     return get_property(data_frame, 'key')
#     662
#     663
#
# ~\anaconda3\envs\em-env\lib\site-packages\py_entitymatching\catalog\catalog_manager.py in get_property(data_frame, property_name)
#      62     if not catalog.is_df_info_present_in_catalog(data_frame):
#      63         logger.error('DataFrame information is not present in the catalog')
# ---> 64         raise KeyError('DataFrame information is not present in the catalog')
#      65
#      66     # Check if the requested property is present in the catalog.
#
# KeyError: 'DataFrame information is not present in the catalog'

# %%
len(C1)

# %% [markdown]
# Debugging blocker output

# %%
# Debug blocker output
# dbg = em.debug_blocker(C1, A, B, output_size=200)

# %%
# # Display first few tuple pairs from the debug_blocker's output
# dbg.head()

# %%
# Updated blocking sequence
# A, B ------ attribute equivalence [city] -----> C1--
#                                                     |----> C
# A, B ------ overlap blocker [name] --------> C2--

# %%
# Create overlap blocker
ob = em.OverlapBlocker()

# # Block tables using 'name' attribute 
# C2 = ob.block_tables(A, B, 'name', 'name', 
#                     l_output_attrs=['name', 'addr', 'city', 'phone'], 
#                     r_output_attrs=['name', 'addr', 'city', 'phone'],
#                     overlap_size=1,
#                     show_progress=False
#                     )

# # Create attribute equivalence blocker
# ab = em.AttrEquivalenceBlocker()

# Block using Director attribute
C2 = ob.block_tables(A, B, "Creator","Creator", 
                    l_output_attrs=["Name", "ReleaseDate", "Director", "Creator", "Cast", "Language" ,"Country", "Genre"], 
                    r_output_attrs=["Name", "ReleaseDate", "Director", "Creator", "Cast", "ContentRating", "Genre"],
                    overlap_size=1
                    )

print(len(C2))

# %%
# Display first two rows from C2
C2.head(2)

# %%
# Combine blocker outputs
C = em.combine_blocker_outputs_via_union([C1, C2])

# %%
len(C)

# %%
# Debug again
# dbg = em.debug_blocker(C, A, B)

# %%
# Display first few rows from the debugger output
# dbg.head(5)

# %% [markdown]
# Matching

# %%
# Sample candidate set
S = em.sample_table(C, 600)

# %%
# Label S
G = em.label_table(S, 'gold')

# %%
# Load the pre-labeled data
path_G = 'labeled_data.csv'
# path_G = em.get_install_path() + os.sep + 'datasets' + os.sep + 'end-to-end' + os.sep + 'restaurants/lbl_restnt_wf1.csv'
G = em.read_csv_metadata(path_G, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='ltable.Id', fk_rtable='rtable.Id')
print(len(G))

# %%
# Split S into development set (I) and evaluation set (J)
IJ = em.split_train_test(G, train_proportion=0.7, random_state=0)
I = IJ['train']
J = IJ['test']

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NaiveBayes')

# %%
# Generate features
feature_table = em.get_features_for_matching(A, B, validate_inferred_attr_types=False)

# %%
# List the names of the features generated
feature_table['feature_name']

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=feature_table, 
                            attrs_after='gold',
                            show_progress=False)

# %%
# Display first few rows
H.head(3)

# %%
H.loc[581,:]

# %%
# Select the best ML matcher using CV
result = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'ltable.Id', 'rtable.Id', 'gold'],
        k=5,
        target_attr='gold', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']

# %%
#  Split feature vectors into train and test
UV = em.split_train_test(H, train_proportion=0.5)
U = UV['train']
V = UV['test']

# %%
# Debug decision tree using GUI
em.vis_debug_rf(rf, U, V, 
        exclude_attrs=['_id', 'ltable.Id', 'rtable.Id', 'gold'],
        target_attr='gold')

# %%
def phone_phone_feature(ltuple, rtuple):
    p1 = ltuple.phone
    p2 = rtuple.phone
    p1 = p1.replace('/','-')
    p1 = p1.replace(' ','')
    p2 = p2.replace('/','-')
    p2 = p2.replace(' ','')    
    if p1 == p2:
        return 1.0
    else:
        return 0.0

# %%
feature_table = em.get_features_for_matching(A, B)
em.add_blackbox_feature(feature_table, 'phone_phone_feature', phone_phone_feature)

# %%
H = em.extract_feature_vecs(I, feature_table=feature_table, attrs_after='gold', show_progress=False)

# %%
# Select the best ML matcher using CV
result = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'gold'],
        k=5,
        target_attr='gold', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']

# %%
# Convert J into a set of feature vectors using feature table
L = em.extract_feature_vecs(J, feature_table=feature_table,
                            attrs_after='gold', show_progress=False)

# %%
# Train using feature vectors from I 
rf.fit(table=H, 
       exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'gold'], 
       target_attr='gold')

# %%
# Predict on L 
predictions = rf.predict(table=L, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'gold'], 
              append=True, target_attr='predicted', inplace=False)

# %%
# Evaluate the predictions
eval_result = em.eval_matches(predictions, 'gold', 'predicted')
em.print_eval_summary(eval_result)
